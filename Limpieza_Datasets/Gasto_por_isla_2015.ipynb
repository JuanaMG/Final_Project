# %%
import pandas as pd

# %%
gasto_isla_2015 = pd.read_csv('../Limpieza_Datasets/data/Gasto_total_isla_2015.csv', sep=';')

# %%
gasto_isla_2015 = gasto_isla_2015.rename(columns={'Unnamed: 0':'Isla',
                                       'Gasto medio por persona':'Gasto por persona',
                                       'Gasto medio diario':'Gasto por persona y día'})

# %%
def espacios (df):
    df.Isla.str.strip()

# %%
espacios(gasto_isla_2015)

# %%
def inicio(df):    
    df.Isla.str.strip()
    df.insert(1, "Mes/año", "")
    
def fecha(df):
    count = 0
    cambioiloc = 0
    lista_general = []
    for i,row in df.iterrows():
        lista_general.append(df.iloc[cambioiloc]["Isla"])
        count += 1    
        if count == 4:
            cambioiloc = (i+1)
            count=0
    df["Mes/año"] = lista_general   

    for i, row in df.iterrows():
        if row['Isla'] in lista_general:
            df.drop(i, inplace=True)

# %%
inicio(gasto_isla_2015)
fecha(gasto_isla_2015)

# %%
def month_year(df):
    df['year'], df['month'] = df["Mes/año"].str.split('M', 1).str
    df.drop(['Mes/año'], axis = 1, inplace= True)

# %%
month_year(gasto_isla_2015)
# Out:
# <ipython-input-8-4b29fdac01bc>:2: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   df['year'], df['month'] = df["Mes/año"].str.split('M', 1).str

# %%
gasto_isla_2015.head(15)
# Out:
#                      Isla Gasto total Gasto por persona y día  \
# 1                Mallorca   1.222.549                  112,89
# 2                 Menorca     150.051                   96,06
# 3      Eivissa-Formentera     430.723                  121,81
# 5                Mallorca   1.837.000                  118,14
# 6                 Menorca     303.470                  105,49
# 7      Eivissa-Formentera     597.859                  125,82
# 9                Mallorca   1.694.900                  117,96
# 10                Menorca     234.841                   99,98
# 11     Eivissa-Formentera     545.116                  125,81
# 13               Mallorca   1.259.589                  113,93
# 14                Menorca     156.388                   96,32
# 15     Eivissa-Formentera     350.307                  118,05
# 17               Mallorca     967.050                  114,68
# 18                Menorca      87.341                   88,33
# 19     Eivissa-Formentera     217.103                  103,84
#
#    Gasto por persona  year month
# 1             919,91  2015    09
# 2             844,17  2015    09
# 3             977,88  2015    09
# 5           1.045,96  2015    08
# 6             966,75  2015    08
# 7             995,54  2015    08
# 9           1.005,22  2015    07
# 10            847,68  2015    07
# 11            975,46  2015    07
# 13             900,9  2015    06
# 14            762,79  2015    06
# 15            832,45  2015    06
# 17            797,57  2015    05
# 18            710,28  2015    05
# 19            716,76  2015    05

# %%
gasto_isla_2015 = gasto_isla_2015[['Isla','Gasto total','Gasto por persona','Gasto por persona y día','year','month']]

# %%
gasto_isla_2015
# Out:
#                       Isla Gasto total Gasto por persona  \
# 1                 Mallorca   1.222.549            919,91
# 2                  Menorca     150.051            844,17
# 3       Eivissa-Formentera     430.723            977,88
# 5                 Mallorca   1.837.000          1.045,96
# 6                  Menorca     303.470            966,75
# ..                     ...         ...               ...
# 250                Menorca     206.609            855,42
# 251     Eivissa-Formentera     472.654          1.052,04
# 253               Mallorca     978.023            891,15
# 254                Menorca     135.293            872,24
# 255     Eivissa-Formentera     311.740            984,79
#
#     Gasto por persona y día  year month
# 1                    112,89  2015    09
# 2                     96,06  2015    09
# 3                    121,81  2015    09
# 5                    118,14  2015    08
# 6                    105,49  2015    08
# ..                      ...   ...   ...
# 250                   94,17  2010    07
# 251                  126,35  2010    07
# 253                  119,27  2010    06
# 254                  105,89  2010    06
# 255                  115,31  2010    06
#
# [192 rows x 6 columns]

# %%
#total_establecim_plazas.to_csv(r'total_establecimientos.csv', index = False, header=True)
